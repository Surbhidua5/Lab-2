# %% [markdown]
# # **OneCat**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_csv('https://raw.githubusercontent.com/holtzy/data_to_viz/master/Example_dataset/7_OneCatOneNum.csv')
data=data.dropna()
data
# Out:
#                 Country    Value
# 0         United States  12394.0
# 1                Russia   6148.0
# 2         Germany (FRG)   1653.0
# 3                France   2162.0
# 4        United Kingdom   1214.0
# 5                 China   1131.0
# 7           Netherlands   1167.0
# 8                 Italy    660.0
# 9                Israel   1263.0
# 10              Ukraine    240.0
# 11                Spain    814.0
# 12               Sweden     83.0
# 13          Switzerland    186.0
# 14               Canada     87.0
# 15          South Korea    587.0
# 16              Belarus     23.0
# 17               Norway    134.0
# 18               Turkey    244.0
# 19         South Africa     74.0
# 20       Czech Republic    110.0
# 21               Poland      3.0
# 22              Belgium     12.0
# 23            Australia     97.0
# 24               Brazil     45.0
# 27              Finland     58.0
# 29                Japan      2.0
# 30             Slovakia     22.0
# ...

# %%
df=data
ordered_df = df.sort_values(by='Value')
my_range=range(1,len(df.index)+1)
 
# The horizontal plot is made using the hline function
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(15)
plt.hlines(y=my_range, xmin=0, xmax=ordered_df['Value'], color='skyblue')
plt.plot(ordered_df['Value'], my_range, "o")
 
# Add titles and axis names
plt.yticks(my_range, ordered_df['Country'])
plt.title("A vertical lolipop plot", loc='left')
plt.xlabel('Value ')
plt.ylabel('Group')
# Out:
# Text(0, 0.5, 'Group')

# %%
df=data
ordered_df = df.sort_values(by='Value')
my_range=range(1,len(df.index)+1)
 
# The horizontal plot is made using the hline function
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(15)
plt.barh(my_range,ordered_df['Value'], color='skyblue')
plt.plot(ordered_df['Value'], my_range, "o")
 
# Add titles and axis names
plt.yticks(my_range, ordered_df['Country'])
plt.title("", loc='left')
plt.xlabel('Value ')
plt.ylabel('Group')
# Out:
# Text(0, 0.5, 'Group')

# %%
# import pandas for data wrangling
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Build a dataset
df=data
# Reorder the dataframe
df = df.sort_values(by=['Value'])

# initialize the figure
plt.figure(figsize=(10,10))
ax = plt.subplot(111, polar=True)
plt.axis('off')

# Constants = parameters controling the plot layout:
upperLimit = 5000
lowerLimit = 5000
labelPadding = 4

# Compute max and min in the dataset
max = df['Value'].max()

# Let's compute heights: they are a conversion of each item value in those new coordinates
# In our example, 0 in the dataset will be converted to the lowerLimit (10)
# The maximum will be converted to the upperLimit (100)
slope = (max - lowerLimit) / max
heights = slope * df.Value + lowerLimit

# Compute the width of each bar. In total we have 2*Pi = 360°
width = 2*np.pi / len(df.index)

# Compute the angle each bar is centered on:
indexes = list(range(1, len(df.index)+1))
angles = [element * width for element in indexes]
angles

# Draw bars
bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=2, 
    edgecolor="white",
    color="#61a4b2",
)

# Add labels
for bar, angle, height, label in zip(bars,angles, heights, df["Country"]):

    # Labels are rotated. Rotation must be specified in degrees :(
    rotation = np.rad2deg(angle)

    # Flip some labels upside down
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    # Finally add the labels
    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor")

# %%
pip install squarify
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# libraries
import matplotlib.pyplot as plt
import squarify    
import pandas as pd
plt.figure(figsize=(30,20))
df = data

# plot it
squarify.plot(sizes=df['Value'], label=df['Country'], alpha=0.9 )
plt.axis('off')
plt.show()

# %%
pip install circlify
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import circlify

df =data
df = df.sort_values('Value') 
circles = circlify.circlify(df['Value'].tolist(),
                            show_enclosure=False,
                            target_enclosure=circlify.Circle(x=0, y=0, r=1))

fig, ax = plt.subplots(figsize=(10, 10))

ax.set_title("")
ax.axis('off')
ax.set_aspect('equal')  # show circles as circles, not as ellipses


l=[]
for circle in circles:
  l.append(float(abs(circle.x) + circle.r))
  l.append(float(abs(circle.y) + circle.r))
lim=l[0]
for i in l:
  if i>lim:
    lim=i;


ax.set_xlim(-lim, lim)
ax.set_ylim(-lim, lim)

labels = df['Country']  # ['B', 'A', 'E', 'C', 'F', 'D']
colors = ['#ffc4c4' if val == df['Value'].max() else '#e6d4ff' for val in df['Value']]
for circle, label, color in zip(circles, labels, colors):
    x, y, r = circle
    ax.add_patch(plt.Circle((x, y), r, alpha=0.7, linewidth=2, color=color))
    ax.annotate(label, (x, y), va='center', ha='center', size=12)
plt.show()

# %% [markdown]
# # **TwoOrMoreCat**

# %%
df2=pd.read_csv('https://raw.githubusercontent.com/holtzy/data_to_viz/master/Example_dataset/14_SeveralIndepLists.csv',sep=" ")
df2
# Out:
#        artist  song                       word
# 0       booba   113                paroles.net
# 1       booba   113                      above
# 2       booba   113                     lyrics
# 3       booba   113                   function
# 4       booba   113                        var
# ...       ...   ...                        ...
# 11524  nekfeu  squa       r.onreadystatechange
# 11525  nekfeu  squa                        NaN
# 11526  nekfeu  squa                   r.onload
# 11527  nekfeu  squa  s.parentnode.insertbefore
# 11528  nekfeu  squa                          r
#
# [11529 rows x 3 columns]

# %%
# Python program to generate WordCloud

# importing all necessary modules
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
import pandas as pd

comment_words = ''
stopwords = set(STOPWORDS)
df= df2[df2["artist"].str.contains("nekfeu") == True]
# iterate through the csv file
for val in df.word:
	
	# typecaste each val to string
	val = str(val)

	# split the value
	tokens = val.split()
	
	# Converts each token into lowercase
	for i in range(len(tokens)):
		tokens[i] = tokens[i].lower()
	
	comment_words += " ".join(tokens)+" "

wordcloud = WordCloud(width = 800, height = 800,
				background_color ='white',
				stopwords = stopwords,
				min_font_size = 10).generate(comment_words)

# plot the WordCloud image					
plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)

plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd


nekfeu_data = df2[df2['artist'] == 'nekfeu']
word_counts = nekfeu_data.groupby('word').count()
top_10_words = word_counts.sort_values('word', ascending=False).head(10)

# plt.barh(range(1,len(top_10_words)+1), top_10_words['word'])

top_10_words
l=[]
for i in nekfeu_data.word:
  a=[list(nekfeu_data.word).count(str(i)),str(i)]
  if a not in l:
    l.append(a)

l=sorted(l,reverse=True)
freq=[]
words=[]
for i in range(9,-1,-1):
  freq.append(l[i][0])
  words.append(l[i][1])
my_range=range(1,11)
plt.hlines(y=my_range, xmin=0, xmax=freq, color='skyblue')
plt.plot(freq, my_range, "o")
 
# Add titles and axis names
plt.yticks(my_range, words)
plt.title("", loc='left')
plt.xlabel('  Count ')
plt.ylabel('Words')
# Out:
# Text(0, 0.5, 'Words')

# %%
from matplotlib_venn import venn3
import pandas as pd

data = df2

booba = set(data[data["artist"] == "booba"]["word"])
nekfeu = set(data[data["artist"] == "nekfeu"]["word"])
brassens = set(data[data["artist"] == "georges-brassens"]["word"])

venn3([booba, nekfeu, brassens], set_labels=("Booba", "Nekfeu", "Brassens"))

plt.show()

# %% [markdown]
# NESTED

# %%
data=pd.read_csv('https://raw.githubusercontent.com/holtzy/data_to_viz/master/Example_dataset/11_SevCatOneNumNestedOneObsPerGroup.csv',sep=';')
data["Continent"]=data['region']
data["Region"]=data['subregion']
data["Country"]=data['key']
data["Pop"]=data['value']
data=data.drop(["region","subregion","key","value"],axis=1)
data
# Out:
#     Continent           Region            Country       Pop
# 0        Asia    Southern Asia        Afghanistan  25500100
# 1      Europe  Northern Europe      Åland Islands     28502
# 2      Europe  Southern Europe            Albania   2821977
# 3      Africa  Northern Africa            Algeria  37900000
# 4     Oceania        Polynesia     American Samoa     55519
# ..        ...              ...                ...       ...
# 245   Oceania        Polynesia  Wallis and Futuna     13135
# 246    Africa  Northern Africa     Western Sahara    567000
# 247      Asia     Western Asia              Yemen  24527000
# 248    Africa   Eastern Africa             Zambia  13092666
# 249    Africa   Eastern Africa           Zimbabwe  12973808
#
# [250 rows x 4 columns]

# %%
import squarify
import matplotlib.pyplot as plt

# data


# create treemap
plt.figure(figsize=(30, 50))
squarify.plot(sizes=data["Pop"], label=data["Region"], alpha=.6)
plt.title("")
plt.axis("off")
plt.show()

# %%
from pytreemap import TreeMap

data = ... # your data here

tree = TreeMap(data, 
    index=["Continent", "Region", "Country"], 
    vSize="Pop", 
    type="index",
    title="",
    palette="Dark2",
    border_col=["black", "grey", "grey"],
    border_lwds=[1, 0.5, 0.1],
    fontsize_labels=[0.7, 0.4, 0.3],
    fontcolor_labels=["white", "white", "black"],
    fontface_labels=1,
    bg_labels=["transparent"],
    align_labels=[["center", "center"], ["left", "top"], ["right", "bottom"]],
    overlap_labels=0.5,
    inflate_labels=True
)

tree.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-9ab1b2ece736> in <module>
#       3 data = ... # your data here
#       4
# ----> 5 tree = TreeMap(data,
#       6     index=["Continent", "Region", "Country"],
#       7     vSize="Pop",
#
# TypeError: __init__() got an unexpected keyword argument 'index'

# %%
pip install pytreemap
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import plotly.express as px
data=data.dropna()
fig = px.treemap(data, path=['Country','Region','Continent'], 
                 values='Pop')
fig.update_layout(margin = dict(t=50, l=25, r=25, b=25))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df=pd.read_csv('https://raw.githubusercontent.com/holtzy/data_to_viz/master/Example_dataset/13_AdjacencyDirectedWeighted.csv',sep=" ")
df.head()
# Out:
#                  Africa  East Asia    Europe  Latin America  North America  \
# Africa         3.142471   0.000000  2.107883       0.000000       0.540887
# East Asia      0.000000   1.630997  0.601265       0.000000       0.973060
# Europe         0.000000   0.000000  2.401476       0.000000       0.000000
# Latin America  0.000000   0.000000  1.762587       0.879198       3.627847
# North America  0.000000   0.000000  1.215929       0.276908       0.000000
#
#                 Oceania  South Asia  South East Asia  Soviet Union  West Asia
# Africa         0.155988         0.0         0.000000           0.0   0.673004
# East Asia      0.333608         0.0         0.380388           0.0   0.869311
# Europe         0.000000         0.0         0.000000           0.0   0.000000
# Latin America  0.000000         0.0         0.000000           0.0   0.000000
# North America  0.000000         0.0         0.000000           0.0   0.000000

# %%
# Package
from networkx.readwrite import json_graph
import json

# I need a long format
data_long = df.melt()
data_long = data_long[data_long["value"] > 0]
data_long.columns = ["source", "target", "value"]
data_long["target"] = data_long["target"] + " "

# From these flows we need to create a node data frame: it lists every entities involved in the flow
nodes = pd.DataFrame({"name": list(set(data_long["source"]).union(set(data_long["target"])))})

# With networkD3, connection must be provided using id, not using real name like in the links dataframe.. So we need to reformat it.
data_long["IDsource"] = data_long["source"].map(lambda x: nodes[nodes["name"] == x].index[0])
data_long["IDtarget"] = data_long["target"].map(lambda x: nodes[nodes["name"] == x].index[0])

# prepare colour scale
ColourScal = 'd3.scaleOrdinal().range(["#FDE725FF","#B4DE2CFF","#6DCD59FF","#35B779FF","#1F9E89FF","#26828EFF","#31688EFF","#3E4A89FF","#482878FF","#440154FF"])'

# Make the Network
sankey = json_graph.node_link_data(data_long, {'source': 'IDsource', 'target': 'IDtarget', 'value': 'value'})
sankey['nodes'] = [{'name': n['name']} for n in sankey['nodes']]
with open('sankey.json', 'w') as f:
    json.dump(sankey, f, indent=4)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-b623cbc3f7c8> in <module>
#       6 data_long = df.melt()
#       7 data_long = data_long[data_long["value"] > 0]
# ----> 8 data_long.columns = ["source", "target", "value"]
#       9 data_long["target"] = data_long["target"] + " "
#      10
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in __setattr__(self, name, value)
#    5498         try:
#    5499             object.__getattribute__(self, name)
# -> 5500             return object.__setattr__(self, name, value)
#    5501         except AttributeError:
#    5502             pass
#
# /usr/local/lib/python3.8/dist-packages/pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/generic.py in _set_axis(self, axis, labels)
# ...

# %%
import plotly.graph_objs as go

# Create the data
data= df.to_numpy()
colnames = ["Africa", "East Asia", "Europe", "Latin Ame.", "North Ame.", "Oceania", "South Asia", "South East Asia", "Soviet Union", "West.Asia"]

# Convert data to long format
data_long = []
for i in range(len(data)):
    for j in range(len(data[i])):
        data_long.append({"from": colnames[i], "to": colnames[j], "value": data[i][j]})

# Create a scatter plot for each connection
scatter_plots = []
for d in data_long:
    scatter_plots.append(go.Scatter(x=[d["from"], d["to"]], y=[0, d["value"]], mode="lines+markers+text",
                                    line=dict(width=1, color="gray"), 
                                    marker=dict(size=8, color="gray"), 
                                    text=[d["value"]],
                                    textposition="middle right"))

# Create a scatter plot for each node
nodes = []
for i, colname in enumerate(colnames):
    nodes.append(go.Scatter(x=[colname], y=[0], mode="markers+text",
                            marker=dict(size=20, color="black"), 
                            text=[colname],
                            textposition="middle center"))

# Create the figure
fig = go.Figure(data=scatter_plots+nodes)

# Set axis labels and title
fig.update_layout(xaxis_title="", yaxis_title="Value", title="Chord Diagram")

# Show the figure
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create the heatmap
sns.heatmap(data, 
            cmap = "YlGnBu",
            cbar = False,
            xticklabels = colnames,
            yticklabels = colnames,
            annot = True,
            fmt = ".1f",
            linewidths = 0.1,
            linecolor = "white",
            annot_kws = {"size": 7})

# Add labels and title
plt.xlabel("")
plt.ylabel("")
plt.title("")

# Show the plot
plt.show()
