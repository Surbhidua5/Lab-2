# %% [markdown]
# # **OneCatOneNum**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data=pd.read_csv('https://raw.githubusercontent.com/holtzy/data_to_viz/master/Example_dataset/7_OneCatOneNum.csv')
data=data.dropna()
data
# Out:
#                 Country    Value
# 0         United States  12394.0
# 1                Russia   6148.0
# 2         Germany (FRG)   1653.0
# 3                France   2162.0
# 4        United Kingdom   1214.0
# 5                 China   1131.0
# 7           Netherlands   1167.0
# 8                 Italy    660.0
# 9                Israel   1263.0
# 10              Ukraine    240.0
# 11                Spain    814.0
# 12               Sweden     83.0
# 13          Switzerland    186.0
# 14               Canada     87.0
# 15          South Korea    587.0
# 16              Belarus     23.0
# 17               Norway    134.0
# 18               Turkey    244.0
# 19         South Africa     74.0
# 20       Czech Republic    110.0
# 21               Poland      3.0
# 22              Belgium     12.0
# 23            Australia     97.0
# 24               Brazil     45.0
# 27              Finland     58.0
# 29                Japan      2.0
# 30             Slovakia     22.0
# ...

# %%
df=data
ordered_df = df.sort_values(by='Value')
my_range=range(1,len(df.index)+1)
 
# The horizontal plot is made using the hline function
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(15)
plt.hlines(y=my_range, xmin=0, xmax=ordered_df['Value'], color='skyblue')
plt.plot(ordered_df['Value'], my_range, "o")
 
# Add titles and axis names
plt.yticks(my_range, ordered_df['Country'])
plt.title("A vertical lolipop plot", loc='left')
plt.xlabel('Value ')
plt.ylabel('Group')
# Out:
# Text(0, 0.5, 'Group')

# %%
df=data
ordered_df = df.sort_values(by='Value')
my_range=range(1,len(df.index)+1)
 
# The horizontal plot is made using the hline function
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(15)
plt.barh(my_range,ordered_df['Value'], color='green')
 
# Add titles and axis names
plt.yticks(my_range, ordered_df['Country'])
plt.title("", loc='left')
plt.xlabel('Value ')
plt.ylabel('Group')
# Out:
# Text(0, 0.5, 'Group')

# %%
# import pandas for data wrangling
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Build a dataset
df=data
# Reorder the dataframe
df = df.sort_values(by=['Value'])

# initialize the figure
plt.figure(figsize=(10,10))
ax = plt.subplot(111, polar=True)
plt.axis('off')

# Constants = parameters controling the plot layout:
upperLimit = 5000
lowerLimit = 5000
labelPadding = 4

# Compute max and min in the dataset
max = df['Value'].max()

# Let's compute heights: they are a conversion of each item value in those new coordinates
# In our example, 0 in the dataset will be converted to the lowerLimit (10)
# The maximum will be converted to the upperLimit (100)
slope = (max - lowerLimit) / max
heights = slope * df.Value + lowerLimit

# Compute the width of each bar. In total we have 2*Pi = 360°
width = 2*np.pi / len(df.index)

# Compute the angle each bar is centered on:
indexes = list(range(1, len(df.index)+1))
angles = [element * width for element in indexes]
angles

# Draw bars
bars = ax.bar(
    x=angles, 
    height=heights, 
    width=width, 
    bottom=lowerLimit,
    linewidth=2, 
    edgecolor="white",
    color="#61a4b2",
)

# Add labels
for bar, angle, height, label in zip(bars,angles, heights, df["Country"]):

    # Labels are rotated. Rotation must be specified in degrees :(
    rotation = np.rad2deg(angle)

    # Flip some labels upside down
    alignment = ""
    if angle >= np.pi/2 and angle < 3*np.pi/2:
        alignment = "right"
        rotation = rotation + 180
    else: 
        alignment = "left"

    # Finally add the labels
    ax.text(
        x=angle, 
        y=lowerLimit + bar.get_height() + labelPadding, 
        s=label, 
        ha=alignment, 
        va='center', 
        rotation=rotation, 
        rotation_mode="anchor")

# %%
pip install squarify
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# libraries
import matplotlib.pyplot as plt
import squarify    
import pandas as pd
plt.figure(figsize=(20,20))
df = data

# plot it
squarify.plot(sizes=df['Value'], label=df['Country'], alpha=0.9 )
plt.axis('off')
plt.show()

# %%
pip install circlify
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd
import circlify

df =data
df = df.sort_values('Value') 
circles = circlify.circlify(df['Value'].tolist(),
                            show_enclosure=False,
                            target_enclosure=circlify.Circle(x=0, y=0, r=1))

fig, ax = plt.subplots(figsize=(10, 10))

ax.set_title("")
ax.axis('off')
ax.set_aspect('equal')  # show circles as circles, not as ellipses


l=[]
for circle in circles:
  l.append(float(abs(circle.x) + circle.r))
  l.append(float(abs(circle.y) + circle.r))
lim=l[0]
for i in l:
  if i>lim:
    lim=i;


ax.set_xlim(-lim, lim)
ax.set_ylim(-lim, lim)

labels = df['Country']  # ['B', 'A', 'E', 'C', 'F', 'D']
colors = ['#ffc4c4' if val == df['Value'].max() else '#e6d4ff' for val in df['Value']]
for circle, label, color in zip(circles, labels, colors):
    x, y, r = circle
    ax.add_patch(plt.Circle((x, y), r, alpha=0.7, linewidth=2, color=color))
    ax.annotate(label, (x, y), va='center', ha='center', size=12)
plt.show()

# %%
df=pd.read_csv('https://raw.githubusercontent.com/zonination/perceptions/master/probly.csv')
df.head()
# Out:
#    Almost Certainly  Highly Likely  Very Good Chance  Probable  Likely  \
# 0              95.0             80                85        75      66
# 1              95.0             75                75        51      75
# 2              95.0             85                85        70      75
# 3              95.0             85                85        70      75
# 4              98.0             95                80        70      70
#
#    Probably  We Believe  Better Than Even  About Even  We Doubt  Improbable  \
# 0        75          66              55.0          50        40        20.0
# 1        51          51              51.0          50        20        49.0
# 2        70          80              60.0          50        30        10.0
# 3        70          80              60.0          50        30        10.0
# 4        75          65              60.0          50        10        50.0
#
#    Unlikely  Probably Not  Little Chance  Almost No Chance  Highly Unlikely  \
# ...

# %%
data = df.melt(  var_name='text', value_name='value')
data['text'] = data['text'].str.replace('.', ' ')
data['value'] = data['value'].round()

# show data
data.sample(8)
# Out:
# <ipython-input-18-79714508d3e1>:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['text'] = data['text'].str.replace('.', ' ')
#                    text  value
# 578        Probably Not   40.0
# 463          Improbable   10.0
# 654    Almost No Chance   15.0
# 775  Chances Are Slight   10.0
# 487          Improbable    7.0
# 569        Probably Not   30.0
# 449            We Doubt   10.0
# 256            Probably   60.0

# %%
# Create a boxplot with jittered points
sns.boxplot(x='text', y='value', data=data, color='grey')
sns.stripplot(x='text', y='value', data=data, size=2, jitter=True, color='black')

# Set the theme and labels
sns.set_theme(style='whitegrid')
plt.xlabel('')
plt.ylabel('Assigned Probability (%)')

# Rotate the x-axis labels
plt.xticks(rotation=90)

plt.show()

# %%
data = data.assign(text = data['text'].astype("category"))
data = data.sort_values("value")

plt.figure(figsize=(10,6))
sns.violinplot(x="text", y="value", data=data, inner="stick", color="blue", saturation=0.5)
plt.xlabel("")
plt.ylabel("Assigned Probability (%)")
plt.xticks(rotation=90)
plt.show()

# %%
annot = pd.DataFrame({
    'text': ["Almost No Chance", "About Even", "Probable", "Almost Certainly"],
    'x': [5, 53, 65, 79],
    'y': [0.15, 0.4, 0.06, 0.1]
})

data = data[data['text'].isin(["Almost No Chance", "About Even", "Probable", "Almost Certainly"])]
data = data.sort_values(by='value')

sns.set_theme(style="darkgrid")
plt.figure(figsize=(12,6))
sns.kdeplot(data['value'],shade=True,color="green",alpha=.6)

plt.xlabel('')
plt.ylabel('Assigned Probability (%)')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data = df.melt(  var_name='text', value_name='value')

data = data.assign(text = data.text.astype("category"))
data = data.sort_values("value", ascending = False)

g = sns.FacetGrid(data, col="text", col_wrap=4, height=3)
g = g.map(sns.kdeplot, "value", shade=True, color = "blue", alpha=0.6)
g.set_titles(size=8)
g.set(xlabel='', ylabel='Assigned Probability (%)')

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data = df.melt(  var_name='text', value_name='value')

data = data.assign(text = data.text.astype("category"))
data = data.sort_values("value", ascending = False)

g = sns.FacetGrid(data, col="text", col_wrap=4, height=3)
g = g.map(sns.histplot, "value", color = "blue", alpha=0.6)
g.set_titles(size=8)
g.set(xlabel='', ylabel='Assigned Probability (%)')

# %%
g= sns.FacetGrid(data, row="text")
g = g.map(sns.kdeplot, "value", color = "blue", alpha=0.6)
g.set_titles(size=8)
g.set(xlabel='', ylabel='Assigned Probability (%)')

# %% [markdown]
# # **OneNumSevCat**

# %%
df1=pd.read_csv('https://raw.githubusercontent.com/holtzy/data_to_viz/master/Example_dataset/9_OneNumSevCatSubgroupOneObs.csv')
df1.head()
# Out:
#      Country  TIME  Value
# 0  Australia  2000   17.2
# 1  Australia  2005   15.8
# 2  Australia  2010   14.0
# 3  Australia  2015   13.0
# 4    Austria  2000   23.1

# %%
plt.figure(figsize=(30,6))
sns.barplot(x="Country", y="Value", hue="TIME", data=df1, dodge=True)
plt.xlabel("Country")
plt.ylabel("gender wage gap (%)")
plt.title("Gender wage gap by country and time")
plt.legend(title="")
plt.show()

# %%
plt.figure(figsize=(30,6))
sns.barplot(x="TIME", y="Value", hue="Country", data=df1)

plt.xlabel("Country")
plt.ylabel("gender wage gap (%)")
plt.title("Gender wage gap by country and time")
plt.legend(title="")
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from plotnine import *
from plotnine.data import mpg

# import data
data = df1

# create groups
all_countries = data['Country'].unique()
grp1 = np.random.choice(all_countries, 20)
grp2 = [x for x in all_countries if x not in grp1]

# filter data
data = data[data['Country'].isin(all_countries) & (data['Country'] != "OECD - Average")]

# add labels
data['label'] = np.where((data['TIME'] == data['TIME'].max()) & data['Country'].isin(grp1), data['Country'], np.nan)
data['label2'] = np.where((data['TIME'] == data['TIME'].min()) & data['Country'].isin(grp2), data['Country'], np.nan)

# create plot
plt.figure(figsize=(10,5))
sns.lineplot(data=data, x='TIME', y='Value', hue='Country')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xlabel("")
plt.ylabel("gender wage gap (%)")

# add labels
for i, txt in enumerate(data['label']):
    if pd.notnull(txt):
        plt.annotate(txt, (data['TIME'][i], data['Value'][i]), xytext=(10,0), textcoords='offset points')
for i, txt in enumerate(data['label2']):
    if pd.notnull(txt):
        plt.annotate(txt, (data['TIME'][i], data['Value'][i]), xytext=(-10,0), textcoords='offset points')

plt.show()
# Out:
# <ipython-input-64-ebf599d7b075>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# <ipython-input-64-ebf599d7b075>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
import plotly.express as px

data =df1

filtered_data = data[(data['TIME'].isin([2000,2015])) & (data['Value'] != -1)]

filtered_data = filtered_data.pivot(index='Country', columns='TIME', values='Value')


fig = px.scatter(filtered_data, x=2000, y=2015, labels={'2000':'Gender wage gap in 2000 (%)', '2015':'Gender wage gap in 2015 (%)'})

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **SevCatOneNum**

# %%
df2=pd.read_csv('https://raw.githubusercontent.com/holtzy/data_to_viz/master/Example_dataset/10_OneNumSevCatSubgroupsSevObs.csv')
df2.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
data=df2

# Group the data by day and sex
counts = data.groupby(['day','sex']).agg({'tip': ['count','median']}).reset_index()
counts.columns = ['day','sex','n','median']

# Reorder the days and set the order
data['day'] = data['day'].astype('category')
data['day'].cat.reorder_categories(["Thur", "Fri", "Sat", "Sun"], inplace=True)

# Create the boxplot
sns.boxplot(x='day', y='tip', hue='sex', data=data, dodge=True, width=0.5)
sns.stripplot(x='day', y='tip', hue='sex', data=data, jitter=True, size=3, alpha=0.5)


# Set the labels and limits
plt.xlabel('')
plt.ylabel('Tip (%)')
plt.ylim(0,15)

# Show the plot
plt.show()
# Out:
# <ipython-input-78-fa5de0b5915c>:9: FutureWarning:
#
# The `inplace` parameter in pandas.Categorical.reorder_categories is deprecated and will be removed in a future version. Reordering categories will always return a new Categorical object.

# %%
import seaborn as sns

data = df2

data = data.assign(day = pd.Categorical(data["day"], categories=["Thur", "Fri", "Sat", "Sun"], ordered=True))
data = data.sort_values(by="day")

plt.figure(figsize=(10,6))
sns.violinplot(x="day", y="tip", hue="sex", data=data, split=True, inner="stick", scale="count", cut=0)
plt.ylim(0,13)
plt.xlabel("")
plt.ylabel("Tip (%)")
plt.legend(title="")
plt.title("Tip Distribution by Day and Sex")
# Out:
# Text(0.5, 1.0, 'Tip Distribution by Day and Sex')

# %%
data=df2
# Reorder and re-factor the day column
data["day"] = data["day"].astype("category")
data["day"] = data["day"].cat.reorder_categories(["Thur", "Fri", "Sat", "Sun"])

# Create the histogram plot
sns.set_theme(style="darkgrid")
g = sns.FacetGrid(data, col="sex", row="time", height=4)
g.map(plt.hist, "tip", bins=20, color="blue", edgecolor="black", alpha=0.7)

g.set_xlabels("")
g.set_ylabels("Tip")

plt.show()

# %%
pip install squarify
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# libraries
import matplotlib.pyplot as plt
import squarify    
import pandas as pd
df3=pd.read_csv('https://raw.githubusercontent.com/holtzy/data_to_viz/master/Example_dataset/11_SevCatOneNumNestedOneObsPerGroup.csv',sep=';')
df3.head()
# Out:
#     region        subregion             key     value
# 0     Asia    Southern Asia     Afghanistan  25500100
# 1   Europe  Northern Europe   Åland Islands     28502
# 2   Europe  Southern Europe         Albania   2821977
# 3   Africa  Northern Africa         Algeria  37900000
# 4  Oceania        Polynesia  American Samoa     55519

# %%
plt.figure(figsize=(30,20))

# plot it
squarify.plot(sizes=df3['value'], label=df3['region'], alpha=0.9 )
plt.axis('off')
plt.show()

# %%
pip install circlify
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
df=df3
ordered_df = df.sort_values(by='value')
my_range=range(1,len(df.index)+1)
 
# The horizontal plot is made using the hline function
f = plt.figure()
f.set_figwidth(10)
f.set_figheight(25)
plt.hlines(y=my_range, xmin=0, xmax=ordered_df['value'], color='skyblue')
plt.plot(ordered_df['value'], my_range, "o")
 
# Add titles and axis names
plt.yticks(my_range, ordered_df['key'])
plt.title("A vertical lolipop plot", loc='left')
plt.xlabel('Value ')
plt.ylabel('Group')
# Out:
# Text(0, 0.5, 'Group')

# %% [markdown]
#  REST OF THE PLOTS ARE REPEATED FROM CATEGORICAL SECTION
